# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('./Titanic/train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape
# Out:
# (891, 12)

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# Cabin          687
# Age            177
# Embarked         2
# Fare             0
# Ticket           0
# Parch            0
# SibSp            0
# Sex              0
# Name             0
# Pclass           0
# Survived         0
# PassengerId      0
# dtype: int64

# %%
persentage = data.isnull().sum()/data.isnull().count()
persentage.sort_values(ascending=False)
# Out:
# Cabin          0.771044
# Age            0.198653
# Embarked       0.002245
# Fare           0.000000
# Ticket         0.000000
# Parch          0.000000
# SibSp          0.000000
# Sex            0.000000
# Name           0.000000
# Pclass         0.000000
# Survived       0.000000
# PassengerId    0.000000
# dtype: float64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
data[['Sex','Survived']].groupby(['Sex']).count()
# Out:
#         Survived
# Sex
# female       314
# male         577

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived as Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
data[['Sex','Survived']].groupby('Sex').mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_ca549ee8_51f6_11ea_90de_5076af1a8f66row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ca549ee8_51f6_11ea_90de_5076af1a8f66row0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_ca549ee8_51f6_11ea_90de_5076af1a8f66row0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_ca549ee8_51f6_11ea_90de_5076af1a8f66row1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_ca549ee8_51f6_11ea_90de_5076af1a8f66row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ca549ee8_51f6_11ea_90de_5076af1a8f66row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ca549ee8_51f6_11ea_90de_5076af1a8f66row2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
# ...

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Survived as Pclass')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_a6616602_51f8_11ea_aba1_5076af1a8f66row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a6616602_51f8_11ea_aba1_5076af1a8f66row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a6616602_51f8_11ea_aba1_5076af1a8f66row0_col2 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_a6616602_51f8_11ea_aba1_5076af1a8f66row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a6616602_51f8_11ea_aba1_5076af1a8f66row1_col0 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_a6616602_51f8_11ea_aba1_5076af1a8f66row1_col1 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_a6616602_51f8_11ea_aba1_5076af1a8f66row1_col2 {
#             background-color:  #f7f0f7;
#             color:  #000000;
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)

# %%
data['Age' ].
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
sns.violinplot('Pclass','Age',hue='Survived',split=True,data=data,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot('Sex','Age',hue='Survived',split=True,data=data,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# Cabin          687
# Age            177
# Embarked         2
# Fare             0
# Ticket           0
# Parch            0
# SibSp            0
# Sex              0
# Name             0
# Pclass           0
# Survived         0
# PassengerId      0
# dtype: int64

# %%
# 年龄的缺失值填充
data['Initial']=0
for i in data:
    # 使用正则表达式：([A-Za-z]+)来提取信息
    data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e40a7ea4_51fe_11ea_98a8_5076af1a8f66row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e40a7ea4_51fe_11ea_98a8_5076af1a8f66row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e40a7ea4_51fe_11ea_98a8_5076af1a8f66row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e40a7ea4_51fe_11ea_98a8_5076af1a8f66row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e40a7ea4_51fe_11ea_98a8_5076af1a8f66row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e40a7ea4_51fe_11ea_98a8_5076af1a8f66row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e40a7ea4_51fe_11ea_98a8_5076af1a8f66row0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
# ...

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir'])
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Mrs
# 887    Miss
# 888      22
# 889      Mr
# 890      Mr
# Name: Initial, Length: 891, dtype: object

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# 5            5.000000
# 22          22.000000
# 32          32.000000
# 36          36.000000
# 42          42.000000
# Capt        70.000000
# Col         58.000000
# Countess    33.000000
# Don         40.000000
# Dr          42.000000
# Jonkheer    38.000000
# Lady        48.000000
# Major       48.500000
# Master       4.574167
# Miss        21.773973
# Mlle        24.000000
# Mme         24.000000
# Mr          32.368090
# Mrs         35.898148
# Ms          28.000000
# Rev         43.166667
# Sir         49.000000
# Name: Age, dtype: float64

# %%
data.loc[data['Age'].isnull()&(data.Initial=='Dr')]=42
data.loc[data['Age'].isnull()&(data.Initial=='Master')]=5
data.loc[data['Age'].isnull()&(data.Initial=='Miss')]=22
data.loc[data['Age'].isnull()&(data.Initial=='Mr')]=32
data.loc[data['Age'].isnull()&(data.Initial=='Mrs')]=36

# %%
data['Age'].isnull().sum()
# Out:
# 0

# %%
f,ax = plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black')
ax[0].set_title('dead')
x = list(range(0,85,5))
ax[0].set_xticks(x)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor='black')
ax[1].set_title('Survived')
ax[1].set_xticks(x)
plt.show()

# %%
f = plt.figure(figsize=(18,8))
sns.factorplot('Pclass','Survived',col='Initial',data=data)
plt.show()

# %%
# 登船地点
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_fe5bbbb4_521e_11ea_bc10_5076af1a8f66row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_fe5bbbb4_521e_11ea_bc10_5076af1a8f66row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_fe5bbbb4_521e_11ea_bc10_5076af1a8f66row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_fe5bbbb4_521e_11ea_bc10_5076af1a8f66row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_fe5bbbb4_521e_11ea_bc10_5076af1a8f66row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_fe5bbbb4_521e_11ea_bc10_5076af1a8f66row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_fe5bbbb4_521e_11ea_bc10_5076af1a8f66row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
# ...
